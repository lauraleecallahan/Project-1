# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from pathlib import Path
import csv

# %%
# File to Load 
gaming_men_to_load = "Data/res.csv"
gaming_anx_to_load = "Data/GamingStudy_data_try2.csv"

# %%
# Read Gaming Data Files and store into Pandas DataFrames
gaming_men = pd.read_csv(gaming_men_to_load)
gaming_anx = pd.read_csv(gaming_anx_to_load)

# %%
gaming_anx.head()
# Out:
#    S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0       1  42052.00437     0     0     0     0     1     0     0
# 1       2  42052.00680     1     2     2     2     0     1     0
# 2       3  42052.03860     0     2     2     0     0     3     1
# 3       4  42052.06804     0     0     0     0     0     0     0
# 4       5  42052.08948     2     1     2     2     2     3     2
#
#                    GADE  ...  SPIN17  Narcissism  Gender  Age  \
# 0  Not difficult at all  ...     0.0         1.0    Male   25
# 1    Somewhat difficult  ...     2.0         1.0    Male   41
# 2  Not difficult at all  ...     2.0         4.0  Female   32
# 3  Not difficult at all  ...     0.0         2.0    Male   28
# 4        Very difficult  ...     0.0         1.0    Male   19
#
#                         Work  \
# 0  Unemployed / between jobs
# 1  Unemployed / between jobs
# 2                   Employed
# 3                   Employed
# 4                   Employed
#
#                                            Playstyle  accept GAD_T SWL_T  \
# 0                                       Singleplayer  Accept     1    23
# 1              Multiplayer - online - with strangers  Accept     8    16
# 2                                       Singleplayer  Accept     8    17
# 3  Multiplayer - online - with online acquaintanc...  Accept     0    17
# 4              Multiplayer - online - with strangers  Accept    14    14
#
#   SPIN_T
# 0    5.0
# 1   33.0
# 2   31.0
# 3   11.0
# 4   13.0
#
# [5 rows x 48 columns]

# %% [markdown]
# #### Clean the Data

# %%
# editing timestamp to show date
gaming_anx['Timestamp'] = pd.to_datetime(gaming_anx['Timestamp'], origin='1899-12-30', unit='D')
gaming_anx.head()
# Out:
#    S. No.                     Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  \
# 0       1 2015-02-17 00:06:17.568000207     0     0     0     0     1     0
# 1       2 2015-02-17 00:09:47.520000241     1     2     2     2     0     1
# 2       3 2015-02-17 00:55:35.039999991     0     2     2     0     0     3
# 3       4 2015-02-17 01:37:58.655999853     0     0     0     0     0     0
# 4       5 2015-02-17 02:08:51.072000207     2     1     2     2     2     3
#
#    GAD7                  GADE  ...  SPIN17  Narcissism  Gender  Age  \
# 0     0  Not difficult at all  ...     0.0         1.0    Male   25
# 1     0    Somewhat difficult  ...     2.0         1.0    Male   41
# 2     1  Not difficult at all  ...     2.0         4.0  Female   32
# 3     0  Not difficult at all  ...     0.0         2.0    Male   28
# 4     2        Very difficult  ...     0.0         1.0    Male   19
#
#                         Work  \
# 0  Unemployed / between jobs
# 1  Unemployed / between jobs
# 2                   Employed
# 3                   Employed
# 4                   Employed
#
#                                            Playstyle  accept GAD_T SWL_T  \
# 0                                       Singleplayer  Accept     1    23
# 1              Multiplayer - online - with strangers  Accept     8    16
# 2                                       Singleplayer  Accept     8    17
# 3  Multiplayer - online - with online acquaintanc...  Accept     0    17
# 4              Multiplayer - online - with strangers  Accept    14    14
#
#   SPIN_T
# 0    5.0
# 1   33.0
# 2   31.0
# 3   11.0
# 4   13.0
#
# [5 rows x 48 columns]

# %%
# dropping highestleague column due to all null results
gaming_anx = gaming_anx.drop('highestleague', axis=1)
print(gaming_anx.columns)
# Out:
# Index(['S. No.', 'Timestamp', 'GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6',
#        'GAD7', 'GADE', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5', 'Platform',
#        'Hours', 'earnings', 'whyplay', 'League', 'streams', 'SPIN1', 'SPIN2',
#        'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8', 'SPIN9', 'SPIN10',
#        'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15', 'SPIN16', 'SPIN17',
#        'Narcissism', 'Gender', 'Age', 'Work', 'Playstyle', 'accept', 'GAD_T',
#        'SWL_T', 'SPIN_T'],
#       dtype='object')

# %%
# Remove rows with any missing values
rows_before = gaming_anx.shape[0]
df_cleaned_no_missing = gaming_anx.dropna()
rows_after = df_cleaned_no_missing.shape[0]

# Display results
rows_removed = rows_before - rows_after
df_cleaned_no_missing.info(), f"Rows removed: {rows_removed}"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3782 entries, 5 to 4998
# Data columns (total 47 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S. No.      3782 non-null   int64
#  1   Timestamp   3782 non-null   datetime64[ns]
#  2   GAD1        3782 non-null   int64
#  3   GAD2        3782 non-null   int64
#  4   GAD3        3782 non-null   int64
#  5   GAD4        3782 non-null   int64
#  6   GAD5        3782 non-null   int64
#  7   GAD6        3782 non-null   int64
#  8   GAD7        3782 non-null   int64
#  9   GADE        3782 non-null   object
#  10  SWL1        3782 non-null   int64
#  11  SWL2        3782 non-null   int64
#  12  SWL3        3782 non-null   int64
#  13  SWL4        3782 non-null   int64
#  14  SWL5        3782 non-null   int64
#  15  Platform    3782 non-null   object
#  16  Hours       3782 non-null   float64
#  17  earnings    3782 non-null   object
#  18  whyplay     3782 non-null   object
#  19  League      3782 non-null   object
#  20  streams     3782 non-null   float64
#  21  SPIN1       3782 non-null   float64
#  22  SPIN2       3782 non-null   float64
#  23  SPIN3       3782 non-null   float64
#  24  SPIN4       3782 non-null   float64
#  25  SPIN5       3782 non-null   float64
#  26  SPIN6       3782 non-null   float64
#  27  SPIN7       3782 non-null   float64
#  28  SPIN8       3782 non-null   float64
#  29  SPIN9       3782 non-null   float64
#  30  SPIN10      3782 non-null   float64
#  31  SPIN11      3782 non-null   float64
#  32  SPIN12      3782 non-null   float64
#  33  SPIN13      3782 non-null   float64
#  34  SPIN14      3782 non-null   float64
#  35  SPIN15      3782 non-null   float64
#  36  SPIN16      3782 non-null   float64
#  37  SPIN17      3782 non-null   float64
#  38  Narcissism  3782 non-null   float64
#  39  Gender      3782 non-null   object
#  40  Age         3782 non-null   int64
#  41  Work        3782 non-null   object
#  42  Playstyle   3782 non-null   object
#  43  accept      3782 non-null   object
#  44  GAD_T       3782 non-null   int64
#  45  SWL_T       3782 non-null   int64
#  46  SPIN_T      3782 non-null   float64
# dtypes: datetime64[ns](1), float64(21), int64(16), object(9)
# memory usage: 1.4+ MB
# (None, 'Rows removed: 1217')

# %%
# Attempt to read the new file and create GAD_Sum and SWL_Sum columns
try:
    # Add a "GAD_Sum" column by summing the specified columns
    df_cleaned_no_missing['GAD_Sum'] = df_cleaned_no_missing[['GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7']].sum(axis=1)
    # Add a "SWL_Sum" column by summing the specified columns
    df_cleaned_no_missing['SWL_Sum'] = df_cleaned_no_missing[['SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5']].sum(axis=1)
    # Display the updated DataFrame structure
    df_cleaned_no_missing[['GAD_Sum', 'SWL_Sum']].head(), df_cleaned_no_missing.info()
except Exception as e:
    e
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3782 entries, 5 to 4998
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S. No.      3782 non-null   int64
#  1   Timestamp   3782 non-null   datetime64[ns]
#  2   GAD1        3782 non-null   int64
#  3   GAD2        3782 non-null   int64
#  4   GAD3        3782 non-null   int64
#  5   GAD4        3782 non-null   int64
#  6   GAD5        3782 non-null   int64
#  7   GAD6        3782 non-null   int64
#  8   GAD7        3782 non-null   int64
#  9   GADE        3782 non-null   object
#  10  SWL1        3782 non-null   int64
#  11  SWL2        3782 non-null   int64
#  12  SWL3        3782 non-null   int64
#  13  SWL4        3782 non-null   int64
#  14  SWL5        3782 non-null   int64
#  15  Platform    3782 non-null   object
#  16  Hours       3782 non-null   float64
#  17  earnings    3782 non-null   object
#  18  whyplay     3782 non-null   object
#  19  League      3782 non-null   object
#  20  streams     3782 non-null   float64
#  21  SPIN1       3782 non-null   float64
#  22  SPIN2       3782 non-null   float64
#  23  SPIN3       3782 non-null   float64
#  24  SPIN4       3782 non-null   float64
#  25  SPIN5       3782 non-null   float64
#  26  SPIN6       3782 non-null   float64
#  27  SPIN7       3782 non-null   float64
#  28  SPIN8       3782 non-null   float64
#  29  SPIN9       3782 non-null   float64
#  30  SPIN10      3782 non-null   float64
#  31  SPIN11      3782 non-null   float64
#  32  SPIN12      3782 non-null   float64
#  33  SPIN13      3782 non-null   float64
#  34  SPIN14      3782 non-null   float64
#  35  SPIN15      3782 non-null   float64
#  36  SPIN16      3782 non-null   float64
#  37  SPIN17      3782 non-null   float64
#  38  Narcissism  3782 non-null   float64
#  39  Gender      3782 non-null   object
#  40  Age         3782 non-null   int64
#  41  Work        3782 non-null   object
#  42  Playstyle   3782 non-null   object
#  43  accept      3782 non-null   object
#  44  GAD_T       3782 non-null   int64
#  45  SWL_T       3782 non-null   int64
#  46  SPIN_T      3782 non-null   float64
#  47  GAD_Sum     3782 non-null   int64
#  48  SWL_Sum     3782 non-null   int64
# dtypes: datetime64[ns](1), float64(21), int64(18), object(9)
# memory usage: 1.4+ MB
# C:\Users\caded\AppData\Local\Temp\ipykernel_16972\2404572959.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_no_missing['GAD_Sum'] = df_cleaned_no_missing[['GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7']].sum(axis=1)
# C:\Users\caded\AppData\Local\Temp\ipykernel_16972\2404572959.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_no_missing['SWL_Sum'] = df_cleaned_no_missing[['SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5']].sum(axis=1)

# %%
print(df_cleaned_no_missing.columns)
# Out:
# Index(['S. No.', 'Timestamp', 'GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6',
#        'GAD7', 'GADE', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5', 'Platform',
#        'Hours', 'earnings', 'whyplay', 'League', 'streams', 'SPIN1', 'SPIN2',
#        'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8', 'SPIN9', 'SPIN10',
#        'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15', 'SPIN16', 'SPIN17',
#        'Narcissism', 'Gender', 'Age', 'Work', 'Playstyle', 'accept', 'GAD_T',
#        'SWL_T', 'SPIN_T', 'GAD_Sum', 'SWL_Sum'],
#       dtype='object')

# %%
# Reordering columns using loc
df_cleaned_no_missing = df_cleaned_no_missing.loc[:, ['S. No.', 'Timestamp', 'GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6',
       'GAD7', 'GADE', 'GAD_Sum', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5','SWL_Sum', 'Platform',
       'Hours', 'earnings', 'whyplay', 'League', 'streams', 'SPIN1', 'SPIN2',
       'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8', 'SPIN9', 'SPIN10',
       'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15', 'SPIN16', 'SPIN17',
       'Narcissism', 'Gender', 'Age', 'Work', 'Playstyle', 'accept', 'GAD_T',
       'SWL_T', 'SPIN_T']]

print(df_cleaned_no_missing.columns)
# Out:
# Index(['S. No.', 'Timestamp', 'GAD1', 'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6',
#        'GAD7', 'GADE', 'GAD_Sum', 'SWL1', 'SWL2', 'SWL3', 'SWL4', 'SWL5',
#        'SWL_Sum', 'Platform', 'Hours', 'earnings', 'whyplay', 'League',
#        'streams', 'SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6',
#        'SPIN7', 'SPIN8', 'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13',
#        'SPIN14', 'SPIN15', 'SPIN16', 'SPIN17', 'Narcissism', 'Gender', 'Age',
#        'Work', 'Playstyle', 'accept', 'GAD_T', 'SWL_T', 'SPIN_T'],
#       dtype='object')

# %% [markdown]
# #### How does game time affect Mental Well-Being?

# %%
# Importing libraries 
import matplotlib.pyplot as plt
import seaborn as sns

# Define bins for Hours and GAD_Sum
hours_bins_5_limited_100 = np.arange(0, 105, 5)  # Hours in increments of 5 up to 100
gad_bins_1 = np.arange(0, 22, 1)  # GAD_Sum in increments of 1

# Create the 2D histogram
heatmap_data_y_1_new, x_edges_5_limited, y_edges_1_new = np.histogram2d(
    df_cleaned_no_missing['Hours'], df_cleaned_no_missing['GAD_Sum'], bins=[hours_bins_5_limited_100, gad_bins_1]
)

# Plot the heatmap
plt.figure(figsize=(16, 10))  # Full-screen dimensions
sns.heatmap(
    heatmap_data_y_1_new.T[::-1],  # Flip the heatmap vertically
    xticklabels=np.round(hours_bins_5_limited_100[:-1], 1),
    yticklabels=gad_bins_1[::-1],  # Flip the GAD_Sum labels
    cmap="Blues",
    cbar_kws={'label': 'Count'},
    annot=False  # Remove annotations
)

# Adjusting labels and titles
plt.title('Heatmap of GAD_Sum vs Hours (Y-Binned in 1s, X-Limit at 100)', fontsize=18)
plt.xlabel('Hours (Binned in 5s)', fontsize=14)
plt.ylabel('GAD_Sum (Descending, Binned in 1s)', fontsize=14)
plt.tight_layout()  # Ensure layout fits well
plt.show()

# %% [markdown]
# #### How does game play affect life satisfaction?

# %%
# Define relevant data
swl_hours_data = df_cleaned_no_missing[['SWL_Sum', 'Hours']].dropna()

# Define bins for Hours and SWL_Sum
hours_bins_5_limited_100 = np.arange(0, 105, 5)  # Hours in increments of 5, up to 100
swl_bins_1 = np.arange(0, swl_hours_data['SWL_Sum'].max() + 2, 1)  # SWL_Sum in increments of 1

# Create the 2D histogram for SWL_Sum and Hours
heatmap_data_swl, x_edges_swl, y_edges_swl = np.histogram2d(
    swl_hours_data['Hours'], swl_hours_data['SWL_Sum'], bins=[hours_bins_5_limited_100, swl_bins_1]
)

# Plot the heatmap with the y-axis starting at 6 and ending at 35
plt.figure(figsize=(16, 10))  # Full-screen dimensions
sns.heatmap(
    heatmap_data_swl.T,  # Do not flip vertically for ascending order
    xticklabels=np.round(hours_bins_5_limited_100[:-1], 1),
    yticklabels=swl_bins_1[0:36],  # Ensure labels from 6 to 35
    cmap="Blues",
    cbar_kws={'label': 'Count'},
    annot=False  # Remove annotations
)

# Adjusting the y-axis to include only values from 6 to 35
plt.ylim(6, 36)  # Limit y-axis to 6 to 35
plt.title('Heatmap of SWL_Sum vs Hours (Y-Binned in 1s, X-Limit at 100, Y-Ascending 6-35)', fontsize=18)
plt.xlabel('Hours (Binned in 5s)', fontsize=14)
plt.ylabel('SWL_Sum (Ascending, Binned in 1s)', fontsize=14)
plt.tight_layout()  # Ensure layout fits well
plt.show()

# %% [markdown]
# ####  Is there a discrepancy in well-being/ life satisfaction between gender, age, and employment?

# %%
# Filter rows where Gender is "Male"
df_male = df_cleaned_no_missing[df_cleaned_no_missing['Gender'] == 'Male']

# Filter rows where Gender is "Female"
df_female = df_cleaned_no_missing[df_cleaned_no_missing['Gender'] == 'Female']


# Histogram for GAD_Sum (Males)
plt.figure(figsize=(12, 6))
sns.histplot(data=df_male, x='GAD_Sum', kde=True, color='blue', bins=15)
plt.title('Histogram of GAD_Sum (Males)', fontsize=16)
plt.xlabel('GAD_Sum', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()
plt.show()

# Histogram for GAD_Sum (Females)
plt.figure(figsize=(12, 6))
sns.histplot(data=df_female, x='GAD_Sum', kde=True, color='pink', bins=15)
plt.title('Histogram of GAD_Sum (Females)', fontsize=16)
plt.xlabel('GAD_Sum', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Out:
# 20.95267054468535

# %%
# Scatter plot with regression for Age vs GAD_Sum
plt.figure(figsize=(12, 6))
sns.regplot(x='Age', y='GAD_Sum', data=df_cleaned_no_missing, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
plt.title('Age vs GAD_Sum', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('GAD_Sum', fontsize=12)
plt.tight_layout()
plt.show()

# Scatter plot with regression for Age vs SWL_Sum
plt.figure(figsize=(12, 6))
sns.regplot(x='Age', y='SWL_Sum', data=df_cleaned_no_missing, scatter_kws={'alpha': 0.6}, line_kws={'color': 'blue'})
plt.title('Age vs SWL_Sum', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('SWL_Sum', fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_cleaned_no_missing["Age"].mean()
# Out:
# 20.95267054468535

# %%
# Bar plot for Work vs GAD_Sum
plt.figure(figsize=(12, 6))
sns.barplot(data=df_cleaned_no_missing, x='Work', y='GAD_Sum', ci='sd', palette='coolwarm')
plt.title('Average GAD_Sum by Work Category', fontsize=16)
plt.xlabel('Work', fontsize=12)
plt.ylabel('Average GAD_Sum', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Bar plot for Work vs SWL_Sum
plt.figure(figsize=(12, 6))
sns.barplot(data=df_cleaned_no_missing, x='Work', y='SWL_Sum', ci='sd', palette='viridis')
plt.title('Average SWL_Sum by Work Category', fontsize=16)
plt.xlabel('Work', fontsize=12)
plt.ylabel('Average SWL_Sum', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\caded\AppData\Local\Temp\ipykernel_16972\4157634684.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_cleaned_no_missing, x='Work', y='GAD_Sum', ci='sd', palette='coolwarm')
# C:\Users\caded\AppData\Local\Temp\ipykernel_16972\4157634684.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_cleaned_no_missing, x='Work', y='GAD_Sum', ci='sd', palette='coolwarm')
# C:\Users\caded\AppData\Local\Temp\ipykernel_16972\4157634684.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_cleaned_no_missing, x='Work', y='SWL_Sum', ci='sd', palette='viridis')
# C:\Users\caded\AppData\Local\Temp\ipykernel_16972\4157634684.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_cleaned_no_missing, x='Work', y='SWL_Sum', ci='sd', palette='viridis')
